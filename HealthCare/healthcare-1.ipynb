# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('cleaned_healthcare.csv')
data
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby Jackson   30    Male         B-            Cancer
# 1           Leslie Terry   62    Male         A+           Obesity
# 2            Danny Smith   76  Female         A-           Obesity
# 3           Andrew Watts   28  Female         O+          Diabetes
# 4          Adrienne Bell   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55488  Elizabeth Jackson   42  Female         O+            Asthma
# 55489         Kyle Perez   61  Female        AB-           Obesity
# 55490       Heather Wang   38  Female         B+      Hypertension
# 55491     Jennifer Jones   43    Male         O-         Arthritis
# 55492       James Garcia   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            31-01-2024     Matthew Smith               Sons And Miller
# ...

# %% [markdown]
# **top rows in data**

# %%
data.head(2)
# Out:
#             Name  Age Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby Jackson   30   Male         B-            Cancer        31-01-2024
# 1   Leslie Terry   62   Male         A+           Obesity        20-08-2019
#
#             Doctor         Hospital Insurance Provider  Billing Amount  \
# 0    Matthew Smith  Sons And Miller         Blue Cross        18856.28
# 1  Samantha Davies          Kim Inc           Medicare        33643.33
#
#    Room Number Admission Type Discharge Date   Medication  Test Results
# 0          328         Urgent     02-02-2024  Paracetamol        Normal
# 1          265      Emergency     26-08-2019    Ibuprofen  Inconclusive

# %% [markdown]
# **last rows**

# %%
data.tail(2)
# Out:
#                  Name  Age  Gender Blood Type Medical Condition  \
# 55491  Jennifer Jones   43    Male         O-         Arthritis
# 55492    James Garcia   53  Female         O+         Arthritis
#
#       Date of Admission          Doctor                  Hospital  \
# 55491        25-05-2019  Kimberly Curry  Jackson Todd And Castro,
# 55492        02-04-2024   Dennis Warren            Henry Sons And
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 55491           Medicare        32451.09          321       Elective
# 55492              Aetna         4010.13          448         Urgent
#
#       Discharge Date Medication Test Results
# 55491     31-05-2019  Ibuprofen     Abnormal
# 55492     29-04-2024  Ibuprofen     Abnormal

# %% [markdown]
# **shape of the dataset**

# %%
data.shape
# Out:
# (55493, 15)

# %%
data.shape[0]
# Out:
# 55493

# %%
data.shape[1]
# Out:
# 15

# %% [markdown]
# **data type of each column**

# %%
data.dtypes
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number             int64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55493 entries, 0 to 55492
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55493 non-null  object
#  1   Age                 55493 non-null  int64
#  2   Gender              55493 non-null  object
#  3   Blood Type          55493 non-null  object
#  4   Medical Condition   55493 non-null  object
#  5   Date of Admission   55493 non-null  object
#  6   Doctor              55493 non-null  object
#  7   Hospital            55493 non-null  object
#  8   Insurance Provider  55493 non-null  object
#  9   Billing Amount      55493 non-null  float64
#  10  Room Number         55493 non-null  int64
#  11  Admission Type      55493 non-null  object
#  12  Discharge Date      55493 non-null  object
#  13  Medication          55493 non-null  object
#  14  Test Results        55493 non-null  object
# ...

# %% [markdown]
# **mean , median std**

# %%
data.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  55493.000000    55493.000000  55493.000000
# mean      51.541816    25539.017188    301.130449
# std       19.602071    14211.483296    115.246730
# min       13.000000    -2008.490000    101.000000
# 25%       35.000000    13240.600000    202.000000
# 50%       52.000000    25538.520000    302.000000
# 75%       68.000000    37820.490000    401.000000
# max       89.000000    52764.280000    500.000000

# %%
data.describe(include='all')
# Out:
#                     Name           Age Gender Blood Type Medical Condition  \
# count              55493  55493.000000  55493      55493             55493
# unique             40231           NaN      2          8                 6
# top     Michael Williams           NaN   Male         A-         Arthritis
# freq                  24           NaN  27770       6968              9307
# mean                 NaN     51.541816    NaN        NaN               NaN
# std                  NaN     19.602071    NaN        NaN               NaN
# min                  NaN     13.000000    NaN        NaN               NaN
# 25%                  NaN     35.000000    NaN        NaN               NaN
# 50%                  NaN     52.000000    NaN        NaN               NaN
# 75%                  NaN     68.000000    NaN        NaN               NaN
# max                  NaN     89.000000    NaN        NaN               NaN
#
# ...

# %% [markdown]
# **to see availiable columns**

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %% [markdown]
# **#To check null values in dataset**
# **#this is calculates column wise**

# %%
data.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.isnull().sum(axis=1)    #Row Wise
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 55488    0
# 55489    0
# 55490    0
# 55491    0
# 55492    0
# Length: 55493, dtype: int64

# %% [markdown]
# **#find unique values grom gender column**

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# **#find the number of unique values from gender columns**

# %%
data['Gender'].nunique()
# Out:
# 2

# %% [markdown]
# **#display count of unique values in gender column**

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      27770
# Female    27723
# Name: count, dtype: int64

# %% [markdown]
# **#find nnumber of patient room no  between 350 to 500 inclusive**

# %%
data['Room Number']>=350
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 55488     True
# 55489    False
# 55490    False
# 55491    False
# 55492     True
# Name: Room Number, Length: 55493, dtype: bool

# %%
data[data['Room Number']<=500]
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby Jackson   30    Male         B-            Cancer
# 1           Leslie Terry   62    Male         A+           Obesity
# 2            Danny Smith   76  Female         A-           Obesity
# 3           Andrew Watts   28  Female         O+          Diabetes
# 4          Adrienne Bell   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55488  Elizabeth Jackson   42  Female         O+            Asthma
# 55489         Kyle Perez   61  Female        AB-           Obesity
# 55490       Heather Wang   38  Female         B+      Hypertension
# 55491     Jennifer Jones   43    Male         O-         Arthritis
# 55492       James Garcia   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            31-01-2024     Matthew Smith               Sons And Miller
# ...

# %%
data[(data['Room Number']>=350) & (data['Room Number']<=500)]
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 3           Andrew Watts   28  Female         O+          Diabetes
# 4          Adrienne Bell   43  Female        AB+            Cancer
# 5         Edward Edwards   21  Female        AB-          Diabetes
# 7       Michelle Daniels   72    Male         O+            Cancer
# 12        Natalie Gamble   46  Female        AB-           Obesity
# ...                  ...  ...     ...        ...               ...
# 55483   Stephanie Oliver   82    Male         B-            Cancer
# 55486       Gloria Bowen   57  Female         B-         Arthritis
# 55487      Jessica White   67    Male         O+         Arthritis
# 55488  Elizabeth Jackson   42  Female         O+            Asthma
# 55492       James Garcia   53  Female         O+         Arthritis
#
#       Date of Admission           Doctor                    Hospital  \
# 3            18-11-2020      Kevin Wells  Hernandez Rogers And Vang,
# ...

# %%
len(data[(data['Room Number']>=350) & (data['Room Number']<=500)])
# Out:
# 21075

# %% [markdown]
# **using between**

# %%
sum(data['Room Number'].between(350,500))
# Out:
# 21075

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %% [markdown]
# **male 1 and female 0**

# %%
data['male_female']=data['Gender'].map({'male':1,'female':0})

# %%
data.head(2)
# Out:
#             Name  Age Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby Jackson   30   Male         B-            Cancer        31-01-2024
# 1   Leslie Terry   62   Male         A+           Obesity        20-08-2019
#
#             Doctor         Hospital Insurance Provider  Billing Amount  \
# 0    Matthew Smith  Sons And Miller         Blue Cross        18856.28
# 1  Samantha Davies          Kim Inc           Medicare        33643.33
#
#    Room Number Admission Type Discharge Date   Medication  Test Results  \
# 0          328         Urgent     02-02-2024  Paracetamol        Normal
# 1          265      Emergency     26-08-2019    Ibuprofen  Inconclusive
#
#    male_female
# 0          NaN
# 1          NaN

# %%
data.drop('male_female',axis=1,inplace=True)

# %%
data.head(2)
# Out:
#             Name  Age Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby Jackson   30   Male         B-            Cancer        31-01-2024
# 1   Leslie Terry   62   Male         A+           Obesity        20-08-2019
#
#             Doctor         Hospital Insurance Provider  Billing Amount  \
# 0    Matthew Smith  Sons And Miller         Blue Cross        18856.28
# 1  Samantha Davies          Kim Inc           Medicare        33643.33
#
#    Room Number Admission Type Discharge Date   Medication  Test Results
# 0          328         Urgent     02-02-2024  Paracetamol        Normal
# 1          265      Emergency     26-08-2019    Ibuprofen  Inconclusive

# %% [markdown]
# **sort the dataframe by 'Date of Admission'**

# %%
data.sort_values(by='Date of Admission')
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 31566       Mary Green   68  Female         B-      Hypertension
# 10860    Timothy Woods   53  Female        AB+           Obesity
# 25199     Brian Oliver   37    Male         O+      Hypertension
# 37605     Amy Phillips   35  Female         A+            Asthma
# 53018     James Murphy   25    Male         O-         Arthritis
# ...                ...  ...     ...        ...               ...
# 45884  Michelle Garcia   43    Male        AB-            Cancer
# 28986  Vernon Robinson   60  Female         A+      Hypertension
# 28721   Thomas Johnson   48  Female         O-         Arthritis
# 11915    Cynthia Price   24    Male         A+            Asthma
# 40418     Kenneth Bean   67    Male         O+         Arthritis
#
#       Date of Admission            Doctor                       Hospital  \
# 31566        01-01-2020       Brian Moore   Montgomery, And Fisher Parks
# ...

# %%
data.sort_values(by='Date of Admission',ascending=False)
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 45884    Michelle Garcia   43    Male        AB-            Cancer
# 16834       Deborah Long   74  Female         B-           Obesity
# 41036      Kelly Schmitt   74  Female         A+         Arthritis
# 50365        Leah Wilson   23    Male         A-           Obesity
# 31879      Wanda Buckley   41    Male        AB+          Diabetes
# ...                  ...  ...     ...        ...               ...
# 40572       Karen Rogers   41    Male         O+          Diabetes
# 10860      Timothy Woods   53  Female        AB+           Obesity
# 8403     Justin Gonzalez   50    Male         B+           Obesity
# 19418         Ann Wright   29  Female         B-      Hypertension
# 47385        Lisa Brooks   58    Male         B-           Obesity
#
#       Date of Admission             Doctor                        Hospital  \
# 45884        31-12-2023         Becky Clay              Contreras And Sons
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %% [markdown]
# **max and min and average age**

# %%
data['Age'].max()
# Out:
# 89

# %%
data['Age'].min()
# Out:
# 13

# %%
data['Age'].mean()
# Out:
# 51.54181608491161

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %% [markdown]
# **find random samples from data (50%)**

# %%
data.sample(frac=0.50)
# Out:
#                  Name  Age  Gender Blood Type Medical Condition  \
# 21466  Steven Johnson   58  Female        AB+          Diabetes
# 50352   Denise Medina   25    Male         O-      Hypertension
# 12255      Erin Patel   18    Male         O+            Cancer
# 12658  Mark Mcpherson   55    Male         O-      Hypertension
# 30492  Michael Martin   80    Male         B+            Asthma
# ...               ...  ...     ...        ...               ...
# 17079     Renee Perez   58  Female        AB+      Hypertension
# 39445   Rachel Rhodes   67    Male         O-      Hypertension
# 30213  Dawn Donaldson   52    Male         A-            Asthma
# 46677    Laura Ramsey   40    Male         A+      Hypertension
# 10777    Tracy Parker   57  Female         A+         Arthritis
#
#       Date of Admission          Doctor                      Hospital  \
# 21466        05-05-2024    David Carter                     Llc Terry
# ...

# %%
data.isin([',']).sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
data.duplicated().any()
# Out:
# True

# %%
data.drop_duplicates()
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby Jackson   30    Male         B-            Cancer
# 1           Leslie Terry   62    Male         A+           Obesity
# 2            Danny Smith   76  Female         A-           Obesity
# 3           Andrew Watts   28  Female         O+          Diabetes
# 4          Adrienne Bell   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55488  Elizabeth Jackson   42  Female         O+            Asthma
# 55489         Kyle Perez   61  Female        AB-           Obesity
# 55490       Heather Wang   38  Female         B+      Hypertension
# 55491     Jennifer Jones   43    Male         O-         Arthritis
# 55492       James Garcia   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            31-01-2024     Matthew Smith               Sons And Miller
# ...
